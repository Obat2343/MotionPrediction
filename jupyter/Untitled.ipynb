# %%
import os
import shutil
import sys

# %%
dataset_dir = os.path.join("../dataset/RLBench3")
target_dir = "/misc/dl001/dataset/ooba/RLBench_for_submit"

task = "PickUpCup"

mode_list = os.listdir("../dataset/RLBench3")
for mode in mode_list:
    task_dir = os.path.join(dataset_dir, mode, task)
    data_index_list = os.listdir(task_dir)
    data_index_list.sort()
    for data_index in data_index_list:
        data_index_dir = os.path.join(task_dir, data_index)
        folder_list = os.listdir(data_index_dir)
        
        target_save_dir = os.path.join(target_dir, mode, task, data_index)
        os.makedirs(target_save_dir, exist_ok=True)
        print("target_save_dir: {}".format(target_save_dir))
        for folder_name in folder_list:
            folder_dir = os.path.join(data_index_dir, folder_name)
            
            if "image" == folder_name:
                image_dir = os.path.join(data_index_dir, folder_name)
                image_list = os.listdir(image_dir)
                image_list.sort()
                
                image_save_dir = os.path.join(target_save_dir, "image")
                os.makedirs(image_save_dir, exist_ok=True)
                for image_name in image_list:
                    if "front" in image_name:
                        shutil.copyfile(os.path.join(image_dir, image_name), os.path.join(image_save_dir, image_name))
            elif os.path.isdir(folder_dir):
                shutil.copytree(folder_dir, os.path.join(target_save_dir, folder_name))
            else:
                shutil.copyfile(folder_dir, os.path.join(target_save_dir, folder_name))
# Out:
# target_save_dir: /misc/dl001/dataset/ooba/RLBench_for_submit/val/PickUpCup/00000
# target_save_dir: /misc/dl001/dataset/ooba/RLBench_for_submit/val/PickUpCup/00001
# target_save_dir: /misc/dl001/dataset/ooba/RLBench_for_submit/val/PickUpCup/00002
# target_save_dir: /misc/dl001/dataset/ooba/RLBench_for_submit/val/PickUpCup/00003
# target_save_dir: /misc/dl001/dataset/ooba/RLBench_for_submit/val/PickUpCup/00004
# target_save_dir: /misc/dl001/dataset/ooba/RLBench_for_submit/val/PickUpCup/00005
# target_save_dir: /misc/dl001/dataset/ooba/RLBench_for_submit/val/PickUpCup/00006
# target_save_dir: /misc/dl001/dataset/ooba/RLBench_for_submit/val/PickUpCup/00007
# target_save_dir: /misc/dl001/dataset/ooba/RLBench_for_submit/val/PickUpCup/00008
# target_save_dir: /misc/dl001/dataset/ooba/RLBench_for_submit/val/PickUpCup/00009
# target_save_dir: /misc/dl001/dataset/ooba/RLBench_for_submit/val/PickUpCup/00010
# target_save_dir: /misc/dl001/dataset/ooba/RLBench_for_submit/val/PickUpCup/00011
# ...

# %% [markdown]
# ---------------------------------------------------------

# %%
dataset_dir = os.path.join("../dataset/HMD/cut_carrot/202009221527/output/")
dataset_dir = os.path.join("../dataset/HMD")
target_dir = "/misc/dl001/dataset/ooba/HMD_for_submit"
os.makedirs(target_dir,exist_ok=True)

task_list = os.listdir(dataset_dir)
for task in task_list:
    task_dir = os.path.join(dataset_dir, task)
    if os.path.isfile(task_dir):
        shutil.copyfile(task_dir, os.path.join(target_dir, task))
        pass
    elif ('else' == task) or ('templete' == task):
        continue
    else:
        data_index_list = os.listdir(task_dir)
        data_index_list.sort()
        for data_index in data_index_list:
            data_index_dir = os.path.join(task_dir, data_index, 'output')
            print(data_index_dir)
        
            target_save_dir = os.path.join(target_dir, task, data_index)
            os.makedirs(target_save_dir, exist_ok=True)
            shutil.copytree(data_index_dir, os.path.join(target_save_dir, 'output'))
            
#         print("target_save_dir: {}".format(target_save_dir))
#         for folder_name in folder_list:
#             folder_dir = os.path.join(data_index_dir, folder_name)
            
#             if "image" == folder_name:
#                 image_dir = os.path.join(data_index_dir, folder_name)
#                 image_list = os.listdir(image_dir)
#                 image_list.sort()
                
#                 image_save_dir = os.path.join(target_save_dir, "image")
#                 os.makedirs(image_save_dir, exist_ok=True)
#                 for image_name in image_list:
#                     if "front" in image_name:
#                         shutil.copyfile(os.path.join(image_dir, image_name), os.path.join(image_save_dir, image_name))
#             elif os.path.isdir(folder_dir):
#                 shutil.copytree(folder_dir, os.path.join(target_save_dir, folder_name))
#             else:
#                 shutil.copyfile(folder_dir, os.path.join(target_save_dir, folder_name))
# Out:
# ../dataset/HMD/cut_carrot/202009221527/output
# ../dataset/HMD/cut_carrot/202009221529/output
# ../dataset/HMD/cut_carrot/202009221530/output
# ../dataset/HMD/cut_carrot/202009221531/output
# ../dataset/HMD/cut_carrot/202009221532/output
# ../dataset/HMD/cut_carrot/202009221534/output
# ../dataset/HMD/cut_carrot/202009221535/output
# ../dataset/HMD/cut_carrot/202009221536/output
# ../dataset/HMD/cut_carrot/202009221537/output
# ../dataset/HMD/cut_carrot/202009221538/output
# ../dataset/HMD/cut_carrot/202009221539/output
# ../dataset/HMD/cut_carrot/202009221540/output
# ../dataset/HMD/cut_carrot/202009221542/output
# ../dataset/HMD/cut_carrot/202009221543/output
# ../dataset/HMD/cut_carrot/202009221546/output
# ../dataset/HMD/cut_carrot/202009221547/output
# ../dataset/HMD/cut_carrot/202009221548/output
# ../dataset/HMD/cut_carrot/202009221549/output
# ../dataset/HMD/cut_carrot/202009221550/output
# ../dataset/HMD/cut_carrot/202009221551/output
# ...
