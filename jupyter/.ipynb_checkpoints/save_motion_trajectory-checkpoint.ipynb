# %% [markdown]
# # make trajectory image

# %%
import os
import pickle
from PIL import Image, ImageDraw
import numpy as np

dataset_root = os.path.abspath("../dataset/RLBench4/val")

for task_name in os.listdir(dataset_root):
    if 'json' in task_name:
        continue
    
    task_dir = os.path.join(dataset_root, task_name)
    for data_index in os.listdir(task_dir):
        print("task:{}  data:{}".format(task_name, data_index))
        data_dir = os.path.join(task_dir, data_index)
        base_data_dir = os.path.join(data_dir, "base_data")
        additional_dir = os.path.join(data_dir, "additional_info")
        os.makedirs(additional_dir, exist_ok=True)
        u_list, v_list = [], []
        pickle_file_list = os.listdir(base_data_dir)
        pickle_file_list.sort()
        for pickle_filename in pickle_file_list:
            with open(os.path.join(base_data_dir, pickle_filename), 'rb') as f:
                pickle_data = pickle.load(f)
                intrinsic_matrix = pickle_data['front_intrinsic_matrix']
                extrinsic_matrix = pickle_data['front_extrinsic_matrix']
                camera2world_matrix = np.linalg.inv(extrinsic_matrix)

                pose = np.append(pickle_data['gripper_pose'][:3], 1)
                pose = np.array(np.dot(camera2world_matrix, pose))
                pose = pose / pose[2]
                uv = np.dot(intrinsic_matrix, pose[:3])
                u_list.append(uv[0])
                v_list.append(uv[1])
        
        for i, pickle_filename in enumerate(pickle_file_list):
            head, ext = os.path.splitext(pickle_filename)
            pos_img = Image.new('L',(256,256))
            d = ImageDraw.Draw(pos_img)
            d.line([(int(u), int(v)) for u, v in zip(u_list[i:],v_list[i:])], fill=(255), width=10) 
            
            img_path = os.path.join(additional_dir, 'goal_trajectory_{}.png'.format(head))
            pos_img.save(img_path)
# Out:
# task:StackWine  data:00001
# task:StackWine  data:00002
# task:StackWine  data:00003
# task:StackWine  data:00004
# task:StackWine  data:00005
# task:StackWine  data:00006
# task:StackWine  data:00007
# task:StackWine  data:00008
# task:StackWine  data:00009
# task:StackWine  data:00010
# task:StackWine  data:00011
# task:StackWine  data:00012
# task:StackWine  data:00013
# task:StackWine  data:00014
# task:StackWine  data:00015
# task:StackWine  data:00016
# task:StackWine  data:00017
# task:StackWine  data:00018
# task:StackWine  data:00019
# task:StackWine  data:00020
# task:StackWine  data:00021
# task:StackWine  data:00022
# task:StackWine  data:00023
# task:StackWine  data:00024
# task:StackWine  data:00025
# task:StackWine  data:00026
# task:StackWine  data:00027
# task:StackWine  data:00028
# task:StackWine  data:00029
# task:StackWine  data:00030
# task:StackWine  data:00031
# task:StackWine  data:00032
# task:StackWine  data:00033
# task:StackWine  data:00034
# task:StackWine  data:00035
# task:StackWine  data:00036
# task:StackWine  data:00037
# task:StackWine  data:00038
# task:StackWine  data:00039
# task:StackWine  data:00040
# task:StackWine  data:00041
# task:StackWine  data:00042
# task:StackWine  data:00043
# task:StackWine  data:00044
# task:StackWine  data:00045
# task:StackWine  data:00046
# task:StackWine  data:00047
# task:StackWine  data:00048
# task:StackWine  data:00049
# task:StackWine  data:00000
# task:PutRubbishInBin  data:00001
# task:PutRubbishInBin  data:00002
# task:PutRubbishInBin  data:00003
# task:PutRubbishInBin  data:00004
# task:PutRubbishInBin  data:00005
# task:PutRubbishInBin  data:00006
# task:PutRubbishInBin  data:00007
# task:PutRubbishInBin  data:00008
# task:PutRubbishInBin  data:00009
# task:PutRubbishInBin  data:00010
# task:PutRubbishInBin  data:00011
# task:PutRubbishInBin  data:00012
# task:PutRubbishInBin  data:00013
# task:PutRubbishInBin  data:00014
# task:PutRubbishInBin  data:00015
# task:PutRubbishInBin  data:00016
# task:PutRubbishInBin  data:00017
# task:PutRubbishInBin  data:00018
# task:PutRubbishInBin  data:00019
# task:PutRubbishInBin  data:00020
# task:PutRubbishInBin  data:00021
# task:PutRubbishInBin  data:00022
# task:PutRubbishInBin  data:00023
# task:PutRubbishInBin  data:00024
# task:PutRubbishInBin  data:00025
# task:PutRubbishInBin  data:00026
# task:PutRubbishInBin  data:00027
# task:PutRubbishInBin  data:00028
# task:PutRubbishInBin  data:00029
# task:PutRubbishInBin  data:00030
# task:PutRubbishInBin  data:00031
# task:PutRubbishInBin  data:00032
# task:PutRubbishInBin  data:00033
# task:PutRubbishInBin  data:00034
# task:PutRubbishInBin  data:00035
# task:PutRubbishInBin  data:00036
# task:PutRubbishInBin  data:00037
# task:PutRubbishInBin  data:00038
# task:PutRubbishInBin  data:00039
# task:PutRubbishInBin  data:00040
# task:PutRubbishInBin  data:00041
# task:PutRubbishInBin  data:00042
# task:PutRubbishInBin  data:00043
# task:PutRubbishInBin  data:00044
# task:PutRubbishInBin  data:00045
# task:PutRubbishInBin  data:00046
# task:PutRubbishInBin  data:00047
# task:PutRubbishInBin  data:00048
# task:PutRubbishInBin  data:00049
# task:PutRubbishInBin  data:00000
# task:PickUpCup  data:00001
# task:PickUpCup  data:00002
# task:PickUpCup  data:00003
# task:PickUpCup  data:00004
# task:PickUpCup  data:00005
# task:PickUpCup  data:00006
# task:PickUpCup  data:00007
# task:PickUpCup  data:00008
# task:PickUpCup  data:00009
# task:PickUpCup  data:00010
# task:PickUpCup  data:00011
# task:PickUpCup  data:00012
# task:PickUpCup  data:00013
# task:PickUpCup  data:00014
# task:PickUpCup  data:00015
# task:PickUpCup  data:00016
# task:PickUpCup  data:00017
# task:PickUpCup  data:00018
# task:PickUpCup  data:00019
# task:PickUpCup  data:00020
# task:PickUpCup  data:00021
# task:PickUpCup  data:00022
# task:PickUpCup  data:00023
# task:PickUpCup  data:00024
# task:PickUpCup  data:00025
# task:PickUpCup  data:00026
# task:PickUpCup  data:00027
# task:PickUpCup  data:00028
# task:PickUpCup  data:00029
# task:PickUpCup  data:00030
# task:PickUpCup  data:00031
# task:PickUpCup  data:00032
# task:PickUpCup  data:00033
# task:PickUpCup  data:00034
# task:PickUpCup  data:00035
# task:PickUpCup  data:00036
# task:PickUpCup  data:00037
# task:PickUpCup  data:00038
# task:PickUpCup  data:00039
# task:PickUpCup  data:00040
# task:PickUpCup  data:00041
# task:PickUpCup  data:00042
# task:PickUpCup  data:00043
# task:PickUpCup  data:00044
# task:PickUpCup  data:00045
# task:PickUpCup  data:00046
# task:PickUpCup  data:00047
# task:PickUpCup  data:00048
# task:PickUpCup  data:00049
# task:PickUpCup  data:00000
# task:PutKnifeOnChoppingBoard  data:00001
# task:PutKnifeOnChoppingBoard  data:00002
# task:PutKnifeOnChoppingBoard  data:00003
# task:PutKnifeOnChoppingBoard  data:00004
# task:PutKnifeOnChoppingBoard  data:00005
# task:PutKnifeOnChoppingBoard  data:00006
# task:PutKnifeOnChoppingBoard  data:00007
# task:PutKnifeOnChoppingBoard  data:00008
# task:PutKnifeOnChoppingBoard  data:00009
# task:PutKnifeOnChoppingBoard  data:00010
# task:PutKnifeOnChoppingBoard  data:00011
# task:PutKnifeOnChoppingBoard  data:00012
# task:PutKnifeOnChoppingBoard  data:00013
# task:PutKnifeOnChoppingBoard  data:00014
# task:PutKnifeOnChoppingBoard  data:00015
# task:PutKnifeOnChoppingBoard  data:00016
# task:PutKnifeOnChoppingBoard  data:00017
# task:PutKnifeOnChoppingBoard  data:00018
# task:PutKnifeOnChoppingBoard  data:00019
# task:PutKnifeOnChoppingBoard  data:00020
# task:PutKnifeOnChoppingBoard  data:00021
# task:PutKnifeOnChoppingBoard  data:00022
# task:PutKnifeOnChoppingBoard  data:00023
# task:PutKnifeOnChoppingBoard  data:00024
# task:PutKnifeOnChoppingBoard  data:00025
# task:PutKnifeOnChoppingBoard  data:00026
# task:PutKnifeOnChoppingBoard  data:00027
# task:PutKnifeOnChoppingBoard  data:00028
# task:PutKnifeOnChoppingBoard  data:00029
# task:PutKnifeOnChoppingBoard  data:00030
# task:PutKnifeOnChoppingBoard  data:00031
# task:PutKnifeOnChoppingBoard  data:00032
# task:PutKnifeOnChoppingBoard  data:00033
# task:PutKnifeOnChoppingBoard  data:00034
# task:PutKnifeOnChoppingBoard  data:00035
# task:PutKnifeOnChoppingBoard  data:00036
# task:PutKnifeOnChoppingBoard  data:00037
# task:PutKnifeOnChoppingBoard  data:00038
# task:PutKnifeOnChoppingBoard  data:00039
# task:PutKnifeOnChoppingBoard  data:00040
# task:PutKnifeOnChoppingBoard  data:00041
# task:PutKnifeOnChoppingBoard  data:00042
# task:PutKnifeOnChoppingBoard  data:00043
# task:PutKnifeOnChoppingBoard  data:00044
# task:PutKnifeOnChoppingBoard  data:00045
# task:PutKnifeOnChoppingBoard  data:00046
# task:PutKnifeOnChoppingBoard  data:00047
# task:PutKnifeOnChoppingBoard  data:00048
# task:PutKnifeOnChoppingBoard  data:00049
# task:PutKnifeOnChoppingBoard  data:00000
# task:TakePlateOffColoredDishRack  data:00001
# task:TakePlateOffColoredDishRack  data:00002
# task:TakePlateOffColoredDishRack  data:00003
# task:TakePlateOffColoredDishRack  data:00004
# task:TakePlateOffColoredDishRack  data:00005
# task:TakePlateOffColoredDishRack  data:00006
# task:TakePlateOffColoredDishRack  data:00007
# task:TakePlateOffColoredDishRack  data:00008
# task:TakePlateOffColoredDishRack  data:00009
# task:TakePlateOffColoredDishRack  data:00010
# task:TakePlateOffColoredDishRack  data:00011
# task:TakePlateOffColoredDishRack  data:00012
# task:TakePlateOffColoredDishRack  data:00013
# task:TakePlateOffColoredDishRack  data:00014
# task:TakePlateOffColoredDishRack  data:00015
# task:TakePlateOffColoredDishRack  data:00016
# task:TakePlateOffColoredDishRack  data:00017
# task:TakePlateOffColoredDishRack  data:00018
# task:TakePlateOffColoredDishRack  data:00019
# task:TakePlateOffColoredDishRack  data:00020
# task:TakePlateOffColoredDishRack  data:00021
# task:TakePlateOffColoredDishRack  data:00022
# task:TakePlateOffColoredDishRack  data:00023
# task:TakePlateOffColoredDishRack  data:00024
# task:TakePlateOffColoredDishRack  data:00025
# task:TakePlateOffColoredDishRack  data:00026
# task:TakePlateOffColoredDishRack  data:00027
# task:TakePlateOffColoredDishRack  data:00028
# task:TakePlateOffColoredDishRack  data:00029
# task:TakePlateOffColoredDishRack  data:00030
# task:TakePlateOffColoredDishRack  data:00031
# task:TakePlateOffColoredDishRack  data:00032
# task:TakePlateOffColoredDishRack  data:00033
# task:TakePlateOffColoredDishRack  data:00034
# task:TakePlateOffColoredDishRack  data:00035
# task:TakePlateOffColoredDishRack  data:00036
# task:TakePlateOffColoredDishRack  data:00037
# task:TakePlateOffColoredDishRack  data:00038
# task:TakePlateOffColoredDishRack  data:00039
# task:TakePlateOffColoredDishRack  data:00040
# task:TakePlateOffColoredDishRack  data:00041
# task:TakePlateOffColoredDishRack  data:00042
# task:TakePlateOffColoredDishRack  data:00043
# task:TakePlateOffColoredDishRack  data:00044
# task:TakePlateOffColoredDishRack  data:00045
# task:TakePlateOffColoredDishRack  data:00046
# task:TakePlateOffColoredDishRack  data:00047
# task:TakePlateOffColoredDishRack  data:00048
# task:TakePlateOffColoredDishRack  data:00049
# task:TakePlateOffColoredDishRack  data:00000

# %% [markdown]
# -------------------------------------------

# %%
import os
import pickle
from PIL import Image, ImageDraw
import numpy as np

dataset_root = os.path.abspath("../dataset/RLBench4/train")

for task_name in os.listdir(dataset_root):
    if 'json' in task_name:
        continue
    
    task_dir = os.path.join(dataset_root, task_name)
    for data_index in os.listdir(task_dir):
        print("task:{}  data:{}".format(task_name, data_index))
        data_dir = os.path.join(task_dir, data_index)
        base_data_dir = os.path.join(data_dir, "base_data")
        additional_dir = os.path.join(data_dir, "additional_info")
        os.makedirs(additional_dir, exist_ok=True)
        u_list, v_list = [], []
        pickle_file_list = os.listdir(base_data_dir)
        pickle_file_list.sort()
        grasp_list = []
        
        for pickle_filename in pickle_file_list:
            with open(os.path.join(base_data_dir, pickle_filename), 'rb') as f:
                pickle_data = pickle.load(f)
                intrinsic_matrix = pickle_data['front_intrinsic_matrix']
                extrinsic_matrix = pickle_data['front_extrinsic_matrix']
                camera2world_matrix = np.linalg.inv(extrinsic_matrix)

                pose = np.append(pickle_data['gripper_pose'][:3], 1)
                pose = np.array(np.dot(camera2world_matrix, pose))
                pose = pose / pose[2]
                uv = np.dot(intrinsic_matrix, pose[:3])
                u_list.append(uv[0])
                v_list.append(uv[1])
# Out:
# task:StackWine  data:00119
# task:StackWine  data:00120
# task:StackWine  data:00122
# task:StackWine  data:00123
# task:StackWine  data:00001
# task:StackWine  data:00002
# task:StackWine  data:00003
# task:StackWine  data:00004
# task:StackWine  data:00000
# task:StackWine  data:00005
# task:StackWine  data:00006
# task:StackWine  data:00007
# task:StackWine  data:00008
# task:StackWine  data:00009
# task:StackWine  data:00010
# task:StackWine  data:00011
# task:StackWine  data:00012
# task:StackWine  data:00013
# task:StackWine  data:00014
# task:StackWine  data:00015
# task:StackWine  data:00016
# task:StackWine  data:00017
# task:StackWine  data:00018
# task:StackWine  data:00019
# task:StackWine  data:00020
# task:StackWine  data:00021
# task:StackWine  data:00022
# task:StackWine  data:00023
# task:StackWine  data:00024
# task:StackWine  data:00025
# task:StackWine  data:00026
# task:StackWine  data:00027
# task:StackWine  data:00028
# task:StackWine  data:00029
# task:StackWine  data:00030
# task:StackWine  data:00031
# task:StackWine  data:00032
# task:StackWine  data:00033
# task:StackWine  data:00034
# task:StackWine  data:00035
# task:StackWine  data:00036
# task:StackWine  data:00037
# task:StackWine  data:00038
# task:StackWine  data:00039
# task:StackWine  data:00040
# task:StackWine  data:00041
# task:StackWine  data:00042
# task:StackWine  data:00043
# task:StackWine  data:00044
# task:StackWine  data:00045
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-6bbf8aac671d> in <module>
#      23
#      24         for pickle_filename in pickle_file_list:
# ---> 25             with open(os.path.join(base_data_dir, pickle_filename), 'rb') as f:
#      26                 pickle_data = pickle.load(f)
#      27                 intrinsic_matrix = pickle_data['front_intrinsic_matrix']
#
# KeyboardInterrupt:

# %%
img = Image.open("../dataset/RLBench3/train/PickUpCup/00001/image/front_rgb_00000000.png")
pos_img = Image.new('L',(256,256))
d = ImageDraw.Draw(img)

img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=256x256 at 0x7F121E991E80>

# %%
u_list
# Out:
# [125.97442211529977,
#  125.95276399647749,
#  125.89217853447231,
#  125.7783846653128,
#  125.61227746936595,
#  125.38554117754082,
#  125.11636349399645,
#  124.78395565030361,
#  124.42621462355831,
#  124.04058457933839,
#  123.62770912139348,
#  123.19379247349522,
#  122.73218965960712,
#  122.25067520662286,
#  121.75840558666508,
#  121.2475801094261,
#  120.7024979909733,
#  120.12988343521641,
#  119.54062638497135,
#  118.93595872233996,
#  118.30742411605569,
#  117.66636865239828,
#  117.01231116253808,
#  116.33660718546159,
#  115.64619473009586,
#  114.9440604451089,
#  114.23138166286928,
#  113.50852652089712,
#  112.76862102373676,
#  112.01450485925355,
#  111.25376515257548,
#  110.48402284198197,
#  109.70289635105034,
#  108.91600328087469,
#  108.127078562258,
#  107.32540769429082,
#  106.51878518547892,
#  105.71220940352535,
#  104.90236350708406,
#  104.08256483231055,
#  103.27214052801538,
#  102.45403201709647,
#  101.6362153910336,
#  100.81732402963037,
#  100.00979607709021,
#  99.2000642509584,
#  98.40007594906321,
#  97.60413325573587,
#  96.81873815122256,
#  96.04024363591388,
#  95.2708455462778,
#  94.51784075782746,
#  93.77627656300548,
#  93.0557905246254,
#  92.33726326346587,
#  91.63956861629666,
#  90.96481128499033,
#  90.30868684200105,
#  89.67216302824895,
#  89.1056667498024,
#  88.64962951527498,
#  88.31042684104055,
#  88.08739645050288,
#  87.98030034597343,
#  88.00548322717714,
#  88.0336605428717,
#  88.07314632012732,
#  88.12964676446173,
#  88.19652328757533,
#  88.2838968644648,
#  88.36059273997563,
#  88.41820035933455,
#  88.45501227071463,
#  88.48139108655775,
#  88.49458477288536,
#  88.49683883461061,
#  88.47426234412139,
#  88.49782927401458,
#  88.50495005870802,
#  88.49217292747278,
#  88.4623628743609,
#  88.43221157601317,
#  88.38852141009804,
#  88.34292872592604,
#  88.2921202208284,
#  88.235637273029,
#  88.17173509670135,
#  88.1065664662708,
#  88.03879356617185,
#  87.97191781131812,
#  87.90133014978343,
#  87.82457384450018,
#  87.74998946492035,
#  87.67366694658,
#  87.59357915646456,
#  87.51334862598094,
#  87.42961579248623,
#  87.34873249109403,
#  87.27748262805707,
#  87.21934599238958,
#  87.17533597966167,
#  87.14984318165878,
#  87.13569470434896,
#  87.13569470434896]

# %%
d.line([(int(u), int(v)) for u, v in zip(u_list,v_list)], fill=(255), width=10) 
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=256x256 at 0x7F121E991E80>

# %%
pickle_data.keys()
# Out:
# dict_keys(['front_extrinsic_matrix', 'front_intrinsic_matrix', 'left_shoulder_extrinsic_matrix', 'left_shoulder_intrinsic_matrix', 'right_shoulder_extrinsic_matrix', 'right_shoulder_intrinsic_matrix', 'wrist_extrinsic_matrix', 'wrist_intrinsic_matrix', 'gripper_joint_positions', 'gripper_matrix', 'gripper_open', 'gripper_pose', 'gripper_touch_forces', 'joint_forces', 'joint_positions', 'joint_velocities', 'joints', 'task_low_dim_state'])

# %%
pickle_data['gripper_pose'][:3]
# Out:
# array([0.30167332, 0.1817728 , 1.1287353 ])

# %%
intrinsic_matrix = pickle_data['front_intrinsic_matrix']
pos_data = np.array(pickle_data['gripper_pose'][:3]) # x,y,z
pos_data = pos_data / pos_data[2] # u,v,1
uv_result = np.dot(intrinsic_matrix, pos_data)

# %%
uv_result[:2]
# Out:
# array([ 79.85652931, 137.46738132])

# %% [markdown]
# ---

# %%
def train_val_split(root_dir, num_val, num_test=0, seed=1):
    # num_val -> validation data for each class
    train_list = []
    val_list = []
    test_list = []

    for actionname in os.listdir(root_dir):
        folder_list = []
        if actionname in ['else', 'templete']:
            continue
        elif os.path.isfile(os.path.join(root_dir, actionname)):
            continue
        
        for foldername in os.listdir(os.path.join(root_dir, actionname)):
            folder_list.append(os.path.join(root_dir, actionname, foldername))
    
        random.seed(seed)
        val_sample = random.sample(folder_list, num_val)
    
        for i in val_sample:
            folder_list.remove(i)

        if num_test > 0:
            test_sample = random.sample(folder_list, num_test)

            for i in test_sample:
                folder_list.remove(i)
            
            test_list.extend(test_sample)

        train_list.extend(folder_list)
        val_list.extend(val_sample)
    
    train_list.sort()
    val_list.sort()
    test_list.sort()

    return train_list, val_list, test_list

# %%
def add_data(self, folder_list):
        # for data preparation
        self.data_dict = {}
        self.data_dict['index_list'] = []
        self.data_dict['action_list'] = []
        self.data_dict['sequence'] = []
        self.data_dict['sequence_index2action'] = []
        image_index = 0
        
        for folder_path in folder_list:
            start_index = image_index
            data_folder_path = os.path.abspath(os.path.join(folder_path,'output'))
            json_path = os.path.abspath(os.path.join(folder_path,'calibration_data','realsensecalib_result.json'))

            csv_list = os.listdir(data_folder_path)
            if len(csv_list) == 4:
                for i in csv_list:
                    if 'calib_pos_' in i:
                        csv_file_name = i
            else:
                csv_file_name = 'calib_pos.csv'
                
            csv_path = os.path.join(data_folder_path,csv_file_name)
            
            df1 = pd.read_csv(csv_path)

            df = df1.loc[:,:'Opti_time']
            for i in self.target_key:
                df2 = df1.loc[:,i]
                df = pd.concat([df,df2],axis=1)

            self.label_list = list(df)
            csv_data_list = df.values.tolist()

            image_name_list = df.loc[:,self.label_list[0]].values.tolist()
            
            hand_data_list = df.loc[:,'hand:1':'hand:15.2'].values.tolist()
            center_check = True
            for i in range(len(image_name_list)):
                if self.skip_until_move:
                    if i == 0:
                        hand_center = self.hand_centor(hand_data_list[i])
                        continue
                    elif center_check:
                        new_hand_center = self.hand_centor(hand_data_list[i])
                        diff = np.sum(np.abs(new_hand_center - hand_center)) / 3
                        hand_center = new_hand_center

                    if diff <= 0.001:
                        continue
                    else:
                        center_check = False

                _, decimal = "{0:.5f}".format(image_name_list[i]).split('.')
                integer, _ = str(image_name_list[i]).split('.')
                integer = integer.zfill(5)
                image_name = "{}.{}.png".format(integer, decimal)
                rgb_image_path = os.path.join(data_folder_path,'RGB',image_name)
                depth_image_path = os.path.join(data_folder_path,'DEPTH',image_name)
                posture = csv_data_list[i]
                action = self.get_action(rgb_image_path)
                if action not in self.data_dict['action_list']:
                    self.data_dict['action_list'].append(action)
                    
                self.data_dict[str(image_index)] = {}
                self.data_dict[str(image_index)]['pose'] = posture
                self.data_dict[str(image_index)]['rgb_image_path'] = rgb_image_path
                self.data_dict[str(image_index)]['depth_image_path'] = depth_image_path
                self.data_dict[str(image_index)]['camera_info'] = self.load_json(json_path)
                self.data_dict[str(image_index)]['action'] = action

                image_index += 1

            for i in range(start_index, image_index - self.pred_len):
                self.data_dict[str(i)]['start_index'] = start_index
                self.data_dict[str(i)]['end_index'] = image_index - 1
                self.data_dict['index_list'].append(i)

            self.data_dict['sequence'].append([start_index, image_index - 1])
            self.data_dict['sequence_index2action'].append(action)

# %%
def split_posdata(pos_data):
    # to split all of position data into each position data
    assert len(pos_data) % 3 == 0, 'dimension of position data is wrong'
    iteration = int(len(pos_data) / 3)
    output_list = []
    for i in range(iteration):
        output_list.append(pos_data[3*i:3*(i+1)])

    return output_list
    
def get_center(pos):
    pos_list = split_posdata(pos)
    center_pos = np.zeros(3)
    nan_count = 0
    for i in pos_list:
        i = np.array(i)
        if sum(np.isnan(i)):
            nan_count += 1
            continue
        center_pos = center_pos + np.array(i)
    center_pos = center_pos / (len(pos_list) - nan_count)
    return center_pos

def add_serial_data(main_data, targetname, start, end, marker=True, semicolon=True):
    if start == 0:
        raise ValueError("start num >= 1")

    for i in range(start, end + 1):
        for j in ["",".1",".2"]:
            if marker:
                main_data.append("{}:Marker{}{}".format(targetname,i,j))
            elif semicolon:
                main_data.append("{}:{}{}".format(targetname,i,j))
            else:
                main_data.append("{}{}{}".format(targetname,i,j))
    return main_data

def load_json(json_path):
    # load json data
    with open(json_path) as f:
        data = f.read()
    data = json.loads(data)
    return data

def transform_pos2image(pos, json_data, image_size):
        uv = get_uv(pos, json_data['dist'], json_data['mtx'])
        pos_image = self.make_pos_image(image_size,uv)
        if self.ToTensor != None:
            pos_image = self.ToTensor(pos_image)
        uv = torch.tensor(uv)[:,:2]
        uv_mask = torch.where(torch.isnan(uv), 0., 1.)
        uv = torch.where(torch.isnan(uv), 0., uv)
        return pos_image, uv, uv_mask

def modify_distortion(vec,dist_vec):
        # modify distortion
        x,y,_ = vec
        r2 = (x*x) + (y*y)
        r4 = r2*r2
        r6 = r4*r2
        dist = dist_vec[0]
        mod_x = x*(1+(dist[0]*r2)+(dist[1]*r4)+(dist[4]*r6)) + 2*dist[2]*x*y + dist[3]*(r2+(2*x*x))
        mod_y = y*(1+(dist[0]*r2)+(dist[1]*r4)+(dist[4]*r6)) + 2*dist[3]*x*y + dist[2]*(r2+(2*y*y))
        ### TODO confirm this effect ###
        return [x,y,1]

def get_uv(pos_data, dist_vec, intrinsic_matrix):
    # transfer position data(based on motive coordinate) to camera coordinate
    split = split_posdata(pos_data)
    uv_result_list = []
    for ins in split:
        ins = np.array(ins)
        ins = ins / ins[2]
        mod_ins = modify_distortion(ins,dist_vec)
        uv_result = np.dot(intrinsic_matrix,mod_ins)
        uv_result_list.append(uv_result)
    return uv_result_list

# %%
import os
import pickle
from PIL import Image, ImageDraw
import numpy as np
import pandas as pd
import json
import shutil

root_dir = os.path.abspath('../dataset/HMD')
folder_list = []

for actionname in os.listdir(root_dir):
    if actionname in ['else', 'templete']:
        continue
    elif os.path.isfile(os.path.join(root_dir, actionname)):
        continue
        
    for foldername in os.listdir(os.path.join(root_dir, actionname)):
        folder_list.append([os.path.join(root_dir, actionname, foldername), actionname])

# %%
data_dict = {}
image_index = 0
target_key = add_serial_data([], "hand", 1, 15, False, True)
target_key = add_serial_data(target_key, "knife", 1 ,6, True)
print(target_key)

for folder_path, action in folder_list:
    print(folder_path)
    start_index = image_index
    data_folder_path = os.path.abspath(os.path.join(folder_path,'output'))
    json_path = os.path.abspath(os.path.join(folder_path,'calibration_data','realsensecalib_result.json'))
    json_data = load_json(json_path)
    
    list_of_folder = os.listdir(data_folder_path)
    for i in list_of_folder:
        print(i)
        if 'calib_pos_' in i:
            csv_file_name = i
            break
        else:
            csv_file_name = 'calib_pos.csv'

    csv_path = os.path.join(data_folder_path,csv_file_name)

    df1 = pd.read_csv(csv_path)

    df = df1.loc[:,:'Opti_time']
    for i in target_key:
        df2 = df1.loc[:,i]
        df = pd.concat([df,df2],axis=1)

    label_list = list(df)
    csv_data_list = df.values.tolist()

    image_name_list = df.loc[:,label_list[0]].values.tolist()

    hand_data_list = df.loc[:,'hand:1':'hand:15.2'].values.tolist()
    knife_data_list = df.loc[:,'knife:Marker1':'knife:Marker6.2'].values.tolist()
    center_check = True
    hand_center_list = []
    knife_center_list = []
    for i in range(len(image_name_list)):
        if i == 0:
            hand_center = get_center(hand_data_list[i])
            hand_center_list.append(get_uv(hand_center, json_data['dist'], json_data['mtx']))
            knife_center = get_center(knife_data_list[i])
            knife_center_list.append(get_uv(knife_center, json_data['dist'], json_data['mtx']))
            valid_index = [0]
            continue
        elif center_check:
            new_hand_center = get_center(hand_data_list[i])
            diff = np.sum(np.abs(new_hand_center - hand_center)) / 3
            hand_center = new_hand_center

        if diff <= 0.001:
            continue
        else:
            center_check = False

        if not center_check:
            valid_index.append(i)

            pos = get_center(hand_data_list[i])
            uv = get_uv(pos, json_data['dist'], json_data['mtx'])
            hand_center_list.append(uv)

            knife_pos = get_center(knife_data_list[i])
            knife_center_list.append(get_uv(knife_pos, json_data['dist'], json_data['mtx']))
    
    print(len(hand_center_list))
    
    trajectory_dir_path = os.path.join(data_folder_path,'trajectory')
    if os.path.exists(trajectory_dir_path):
        shutil.rmtree(trajectory_dir_path)
    os.makedirs(trajectory_dir_path, exist_ok=True)
    
    for i in range(len(hand_center_list)):
        image_name = image_name_list[valid_index[i]]
        _, decimal = "{0:.5f}".format(image_name).split('.')
        integer, _ = str(image_name).split('.')
        integer = integer.zfill(5)
        image_name = "{}.{}.png".format(integer, decimal)
        image_hand_name = "hand_{}.{}.png".format(integer, decimal)
        image_knife_name = "knife_{}.{}.png".format(integer, decimal)
        
        rgb_image_path = os.path.join(data_folder_path,'RGB',image_name)
        rgb_image = Image.open(rgb_image_path)
        
        trajectory_image_path = os.path.join(trajectory_dir_path, image_name)
        trajectory_hand_path = os.path.join(trajectory_dir_path, image_hand_name)
        trajectory_knife_path = os.path.join(trajectory_dir_path, image_knife_name)
        
        pos_img_hand = Image.new('L',(448,224))
        d_hand = ImageDraw.Draw(pos_img_hand)
        pos_img_knife = Image.new('L',(448,224))
        d_knife = ImageDraw.Draw(pos_img_knife)
        
        d = ImageDraw.Draw(rgb_image)
        d.line([(int(uv[0][0]), int(uv[0][1])) for uv in hand_center_list[i:]], fill=(255), width=10)
        d_hand.line([(int(uv[0][0]), int(uv[0][1])) for uv in hand_center_list[i:]], fill=(255), width=10) 
        
        if 'move' not in action:
            d.line([(int(uv[0][0]), int(uv[0][1])) for uv in knife_center_list[i:]], fill=(255,0,255), width=10) 
            d_knife.line([(int(uv[0][0]), int(uv[0][1])) for uv in knife_center_list[i:]], fill=(255), width=10)
            pos_img_knife.save(trajectory_knife_path)
        
        rgb_image.save(trajectory_image_path)
        pos_img_hand.save(trajectory_hand_path)
# Out:
# ['hand:1', 'hand:1.1', 'hand:1.2', 'hand:2', 'hand:2.1', 'hand:2.2', 'hand:3', 'hand:3.1', 'hand:3.2', 'hand:4', 'hand:4.1', 'hand:4.2', 'hand:5', 'hand:5.1', 'hand:5.2', 'hand:6', 'hand:6.1', 'hand:6.2', 'hand:7', 'hand:7.1', 'hand:7.2', 'hand:8', 'hand:8.1', 'hand:8.2', 'hand:9', 'hand:9.1', 'hand:9.2', 'hand:10', 'hand:10.1', 'hand:10.2', 'hand:11', 'hand:11.1', 'hand:11.2', 'hand:12', 'hand:12.1', 'hand:12.2', 'hand:13', 'hand:13.1', 'hand:13.2', 'hand:14', 'hand:14.1', 'hand:14.2', 'hand:15', 'hand:15.1', 'hand:15.2', 'knife:Marker1', 'knife:Marker1.1', 'knife:Marker1.2', 'knife:Marker2', 'knife:Marker2.1', 'knife:Marker2.2', 'knife:Marker3', 'knife:Marker3.1', 'knife:Marker3.2', 'knife:Marker4', 'knife:Marker4.1', 'knife:Marker4.2', 'knife:Marker5', 'knife:Marker5.1', 'knife:Marker5.2', 'knife:Marker6', 'knife:Marker6.1', 'knife:Marker6.2']
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/cut_carrot/202009221527
# DEPTH
# RGB
# calib_pos.csv
# trajectory
# 33
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/cut_carrot/202009221529
# DEPTH
# RGB
# calib_pos.csv
# trajectory
# 35
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/cut_carrot/202009221530
# DEPTH
# RGB
# calib_pos.csv
# trajectory
# 23
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/cut_carrot/202009221531
# DEPTH
# RGB
# calib_pos.csv
# trajectory
# 33
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/cut_carrot/202009221532
# DEPTH
# RGB
# calib_pos.csv
# trajectory
# 42
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/cut_carrot/202009221534
# DEPTH
# RGB
# calib_pos.csv
# trajectory
# 38
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/cut_carrot/202009221535
# DEPTH
# RGB
# calib_pos.csv
# trajectory
# 46
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/cut_carrot/202009221536
# DEPTH
# RGB
# calib_pos.csv
# trajectory
# 38
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/cut_carrot/202009221537
# DEPTH
# RGB
# calib_pos.csv
# calib_pos_-0.008333333333333318.csv
# 24
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/cut_carrot/202009221538
# DEPTH
# RGB
# calib_pos.csv
# trajectory
# 16
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/cut_carrot/202009221539
# DEPTH
# RGB
# calib_pos.csv
# trajectory
# 36
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/cut_carrot/202009221540
# DEPTH
# RGB
# calib_pos.csv
# calib_pos_0.16666666666666674.csv
# 38
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/cut_carrot/202009221542
# DEPTH
# RGB
# calib_pos.csv
# trajectory
# 54
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/cut_carrot/202009221543
# DEPTH
# RGB
# calib_pos.csv
# trajectory
# 57
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/cut_carrot/202009221546
# DEPTH
# RGB
# calib_pos.csv
# trajectory
# 29
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/cut_carrot/202009221547
# DEPTH
# RGB
# calib_pos.csv
# trajectory
# 60
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/cut_carrot/202009221548
# DEPTH
# RGB
# calib_pos.csv
# trajectory
# 39
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/cut_carrot/202009221549
# DEPTH
# RGB
# calib_pos.csv
# trajectory
# 33
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/cut_carrot/202009221550
# DEPTH
# RGB
# calib_pos.csv
# trajectory
# 23
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/cut_carrot/202009221551
# DEPTH
# RGB
# calib_pos.csv
# trajectory
# 25
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/cut_carrot/202009221552
# DEPTH
# RGB
# calib_pos.csv
# calib_pos_-0.0833333333333333.csv
# 29
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/cut_cucumber/202008020618
# DEPTH
# RGB
# calib_pos.csv
# trajectory
# 50
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/cut_cucumber/202008020620
# DEPTH
# RGB
# calib_pos.csv
# trajectory
# 49
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/cut_cucumber/202008020626
# DEPTH
# RGB
# calib_pos.csv
# trajectory
# 64
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/cut_cucumber/202008020627
# DEPTH
# RGB
# calib_pos.csv
# calib_pos_-0.0833333333333333.csv
# 50
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/cut_cucumber/202008020629
# DEPTH
# RGB
# calib_pos.csv
# trajectory
# 54
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/cut_cucumber/202008020635
# DEPTH
# RGB
# calib_pos.csv
# trajectory
# 44
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/cut_cucumber/202008020636
# DEPTH
# RGB
# calib_pos.csv
# trajectory
# 37
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/cut_cucumber/202008031816
# DEPTH
# RGB
# calib_pos.csv
# trajectory
# 53
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/cut_cucumber/202008031819
# DEPTH
# RGB
# calib_pos.csv
# trajectory
# 45
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/cut_cucumber/202008031821
# DEPTH
# RGB
# calib_pos.csv
# trajectory
# 67
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/cut_cucumber/202008031823
# DEPTH
# RGB
# calib_pos.csv
# trajectory
# 43
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/cut_cucumber/202009091825
# DEPTH
# RGB
# calib_pos.csv
# calib_pos_-0.008333333333333318.csv
# 31
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/cut_cucumber/202009091826
# DEPTH
# RGB
# calib_pos.csv
# trajectory
# 28
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/cut_cucumber/202009091827
# DEPTH
# RGB
# calib_pos.csv
# trajectory
# 22
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/cut_cucumber/202009091829
# DEPTH
# RGB
# calib_pos.csv
# trajectory
# 30
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/cut_cucumber/202009091830
# DEPTH
# RGB
# calib_pos.csv
# calib_pos_-0.0833333333333333.csv
# 39
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/cut_cucumber/202009091831
# DEPTH
# RGB
# calib_pos.csv
# trajectory
# 32
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/cut_cucumber/202009091832
# DEPTH
# RGB
# calib_pos.csv
# trajectory
# 24
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/cut_cucumber/202009091834
# DEPTH
# RGB
# calib_pos.csv
# trajectory
# 25
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/cut_cucumber/202009091835
# DEPTH
# RGB
# calib_pos.csv
# trajectory
# 25
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/cut_cucumber/202009091836
# DEPTH
# RGB
# calib_pos.csv
# trajectory
# 28
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/cut_cucumber/202009091837
# DEPTH
# RGB
# calib_pos.csv
# trajectory
# 26
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/cut_cucumber/202009091838
# DEPTH
# RGB
# calib_pos.csv
# calib_pos_0.11666666666666668.csv
# 25
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/cut_cucumber/202009091839
# DEPTH
# RGB
# calib_pos.csv
# trajectory
# 24
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/cut_cucumber/202009091841
# DEPTH
# RGB
# calib_pos.csv
# trajectory
# 26
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/cut_cucumber/202009091842
# DEPTH
# RGB
# calib_pos.csv
# trajectory
# 24
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/cut_cucumber/202009091843
# DEPTH
# RGB
# calib_pos.csv
# trajectory
# 30
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/cut_cucumber/202009091844
# DEPTH
# RGB
# calib_pos.csv
# calib_pos_0.16666666666666674.csv
# 21
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/cut_cucumber/202009091845
# DEPTH
# RGB
# calib_pos.csv
# trajectory
# 19
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/cut_cucumber/202009091846
# DEPTH
# RGB
# calib_pos.csv
# calib_pos_-0.03333333333333331.csv
# 27
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/cut_cucumber/202009091847
# DEPTH
# RGB
# calib_pos.csv
# calib_pos_-0.008333333333333318.csv
# 16
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/cut_cucumber/202009091849
# DEPTH
# RGB
# calib_pos.csv
# calib_pos_-0.0833333333333333.csv
# 20
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/cut_cucumber/202009091850
# DEPTH
# RGB
# calib_pos.csv
# calib_pos_0.11666666666666668.csv
# 20
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/cut_cucumber/202009091851
# DEPTH
# RGB
# calib_pos.csv
# trajectory
# 25
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/cut_cucumber/202009091852
# DEPTH
# RGB
# calib_pos.csv
# trajectory
# 21
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/cut_cucumber/202009091853
# DEPTH
# RGB
# calib_pos.csv
# trajectory
# 17
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/cut_cucumber/202009091854
# DEPTH
# RGB
# calib_pos.csv
# trajectory
# 21
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/cut_cucumber/202009091855
# DEPTH
# RGB
# calib_pos.csv
# calib_pos_-0.08333333333333333.csv
# 21
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/cut_cucumber/202009211811
# DEPTH
# RGB
# calib_pos.csv
# calib_pos_-0.08333333333333333.csv
# 24
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/cut_cucumber/202009211813
# DEPTH
# RGB
# calib_pos.csv
# calib_pos_0.06666666666666667.csv
# 27
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/cut_cucumber/202009211814
# DEPTH
# RGB
# calib_pos.csv
# trajectory
# 26
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/cut_cucumber/202009211815
# DEPTH
# RGB
# calib_pos.csv
# calib_pos_0.09166666666666666.csv
# 26
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/cut_cucumber/202009211816
# DEPTH
# RGB
# calib_pos.csv
# calib_pos_-0.2583333333333333.csv
# 22
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/cut_cucumber/202009211817
# DEPTH
# RGB
# calib_pos.csv
# trajectory
# 23
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/cut_cucumber/202009211818
# DEPTH
# RGB
# calib_pos.csv
# calib_pos_0.11666666666666668.csv
# 22
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/cut_cucumber/202009211820
# DEPTH
# RGB
# calib_pos.csv
# calib_pos_0.11666666666666668.csv
# 23
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/cut_cucumber/202009211821
# DEPTH
# RGB
# calib_pos.csv
# trajectory
# 22
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/cut_cucumber/202009211822
# DEPTH
# RGB
# calib_pos.csv
# trajectory
# 28
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/cut_cucumber/202009211826
# DEPTH
# RGB
# calib_pos.csv
# calib_pos_0.11666666666666668.csv
# 19
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/cut_cucumber/202009211827
# DEPTH
# RGB
# calib_pos.csv
# calib_pos_-0.13333333333333336.csv
# 24
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/cut_cucumber/202009211828
# DEPTH
# RGB
# calib_pos.csv
# trajectory
# 23
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/cut_cucumber/202009211829
# DEPTH
# RGB
# calib_pos.csv
# trajectory
# 19
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/cut_cucumber/202009211830
# DEPTH
# RGB
# calib_pos.csv
# trajectory
# 23
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/cut_cucumber/202009211831
# DEPTH
# RGB
# calib_pos.csv
# trajectory
# 19
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/cut_cucumber/202009211832
# DEPTH
# RGB
# calib_pos.csv
# trajectory
# 25
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/cut_cucumber/202009211833
# DEPTH
# RGB
# calib_pos.csv
# trajectory
# 21
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/cut_cucumber/202009211834
# DEPTH
# RGB
# calib_pos.csv
# trajectory
# 21
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/cut_cucumber/202009211835
# DEPTH
# RGB
# calib_pos.csv
# trajectory
# 20
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/cut_cucumber/202009211836
# DEPTH
# RGB
# calib_pos.csv
# trajectory
# 23
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/cut_cucumber/202009211838
# DEPTH
# RGB
# calib_pos.csv
# trajectory
# 23
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/cut_cucumber/202009211839
# DEPTH
# RGB
# calib_pos.csv
# trajectory
# 24
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/cut_cucumber/202009211840
# DEPTH
# RGB
# calib_pos.csv
# trajectory
# 19
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/cut_cucumber/202009211842
# DEPTH
# RGB
# calib_pos.csv
# trajectory
# 21
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/cut_cucumber/202009211843
# DEPTH
# RGB
# calib_pos.csv
# trajectory
# 20
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/cut_cucumber/202009211844
# DEPTH
# RGB
# calib_pos.csv
# trajectory
# 28
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/cut_eggplant/202008051750
# DEPTH
# RGB
# calib_pos.csv
# trajectory
# 69
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/cut_eggplant/202008051751
# DEPTH
# RGB
# calib_pos.csv
# trajectory
# 52
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/cut_eggplant/202008051753
# DEPTH
# RGB
# calib_pos.csv
# trajectory
# 44
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/cut_eggplant/202008051754
# DEPTH
# RGB
# calib_pos.csv
# trajectory
# 73
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/cut_eggplant/202008051756
# DEPTH
# RGB
# calib_pos.csv
# trajectory
# 56
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/cut_eggplant/202008051758
# DEPTH
# RGB
# calib_pos.csv
# trajectory
# 57
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/cut_eggplant/202008051800
# DEPTH
# RGB
# calib_pos.csv
# trajectory
# 50
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/cut_eggplant/202008051802
# DEPTH
# RGB
# calib_pos.csv
# trajectory
# 52
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/cut_eggplant/202008051804
# DEPTH
# RGB
# calib_pos.csv
# trajectory
# 45
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/cut_eggplant/202009151911
# DEPTH
# RGB
# calib_pos.csv
# calib_pos_-0.008333333333333318.csv
# 43
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/cut_eggplant/202009151912
# DEPTH
# RGB
# calib_pos.csv
# trajectory
# 53
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/cut_eggplant/202009151913
# DEPTH
# RGB
# calib_pos.csv
# calib_pos_0.11666666666666668.csv
# 52
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/cut_eggplant/202009151915
# DEPTH
# RGB
# calib_pos.csv
# trajectory
# 43
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/cut_eggplant/202009151916
# DEPTH
# RGB
# calib_pos.csv
# trajectory
# 36
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/cut_eggplant/202009151917
# DEPTH
# RGB
# calib_pos.csv
# trajectory
# 46
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/cut_eggplant/202009151918
# DEPTH
# RGB
# calib_pos.csv
# trajectory
# 40
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/cut_eggplant/202009151922
# DEPTH
# RGB
# calib_pos.csv
# trajectory
# 33
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/cut_eggplant/202009151923
# DEPTH
# RGB
# calib_pos.csv
# trajectory
# 43
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/cut_eggplant/202009151924
# DEPTH
# RGB
# calib_pos.csv
# trajectory
# 38
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/cut_eggplant/202009151926
# DEPTH
# RGB
# calib_pos.csv
# trajectory
# 30
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/cut_eggplant/202009151927
# DEPTH
# RGB
# calib_pos.csv
# trajectory
# 34
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/cut_eggplant/202009151928
# DEPTH
# RGB
# calib_pos.csv
# calib_pos_0.16666666666666669.csv
# 30
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/cut_eggplant/202009151929
# DEPTH
# RGB
# calib_pos.csv
# trajectory
# 36
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/cut_eggplant/202009151930
# DEPTH
# RGB
# calib_pos.csv
# calib_pos_-0.10833333333333335.csv
# 43
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/cut_eggplant/202009151932
# DEPTH
# RGB
# calib_pos.csv
# trajectory
# 31
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/cut_eggplant/202009151933
# DEPTH
# RGB
# calib_pos.csv
# trajectory
# 36
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/cut_eggplant/202009151934
# DEPTH
# RGB
# calib_pos.csv
# calib_pos_-0.15833333333333333.csv
# 30
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/cut_eggplant/202009151935
# DEPTH
# RGB
# calib_pos.csv
# trajectory
# 34
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/cut_eggplant/202009151936
# DEPTH
# RGB
# calib_pos.csv
# calib_pos_0.09166666666666666.csv
# 32
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/cut_sp/202009211720
# DEPTH
# RGB
# calib_pos.csv
# calib_pos_-0.13333333333333336.csv
# 57
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/cut_sp/202009211722
# DEPTH
# RGB
# calib_pos.csv
# trajectory
# 41
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/cut_sp/202009211723
# DEPTH
# RGB
# calib_pos.csv
# trajectory
# 39
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/cut_sp/202009211724
# DEPTH
# RGB
# calib_pos.csv
# calib_pos_-0.10833333333333335.csv
# 33
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/cut_sp/202009211726
# DEPTH
# RGB
# calib_pos.csv
# calib_pos_-0.13333333333333336.csv
# 37
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/cut_sp/202009211727
# DEPTH
# RGB
# calib_pos.csv
# calib_pos_0.11666666666666668.csv
# 38
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/cut_sp/202009211728
# DEPTH
# RGB
# calib_pos.csv
# trajectory
# 39
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/cut_sp/202009211729
# DEPTH
# RGB
# calib_pos.csv
# calib_pos_0.11666666666666668.csv
# 30
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/cut_sp/202009211730
# DEPTH
# RGB
# calib_pos.csv
# calib_pos_0.11666666666666668.csv
# 30
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/cut_sp/202009211740
# DEPTH
# RGB
# calib_pos.csv
# calib_pos_-0.13333333333333336.csv
# 48
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/cut_sp/202009211741
# DEPTH
# RGB
# calib_pos.csv
# calib_pos_0.09166666666666666.csv
# 32
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/cut_sp/202009211747
# DEPTH
# RGB
# calib_pos.csv
# trajectory
# 48
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/cut_sp/202009211749
# DEPTH
# RGB
# calib_pos.csv
# trajectory
# 32
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/cut_sp/202009211750
# DEPTH
# RGB
# calib_pos.csv
# calib_pos_0.09166666666666666.csv
# 35
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/cut_sp/202009211751
# DEPTH
# RGB
# calib_pos.csv
# trajectory
# 48
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/cut_sp/202009211752
# DEPTH
# RGB
# calib_pos.csv
# calib_pos_0.09166666666666666.csv
# 53
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/cut_sp/202009211753
# DEPTH
# RGB
# calib_pos.csv
# trajectory
# 38
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/cut_sp/202009211754
# DEPTH
# RGB
# calib_pos.csv
# calib_pos_-0.08333333333333333.csv
# 35
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/cut_sp/202009211755
# DEPTH
# RGB
# calib_pos.csv
# trajectory
# 42
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/cut_sp/202009211756
# DEPTH
# RGB
# calib_pos.csv
# trajectory
# 37
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/cut_sp/202009211758
# DEPTH
# RGB
# calib_pos.csv
# trajectory
# 30
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/cut_sp/202009211759
# DEPTH
# RGB
# calib_pos.csv
# trajectory
# 33
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/cut_sp/202009211800
# DEPTH
# RGB
# calib_pos.csv
# trajectory
# 36
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/cut_sp/202009211801
# DEPTH
# RGB
# calib_pos.csv
# trajectory
# 42
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/cut_sp/202009211802
# DEPTH
# RGB
# calib_pos.csv
# trajectory
# 38
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_bottle/202007241605
# DEPTH
# RGB
# calib_pos.csv
# trajectory
# 87
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/env/dl11/lib/python3.6/site-packages/ipykernel_launcher.py:21: RuntimeWarning: invalid value encountered in true_divide
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_bottle/202009151715
# DEPTH
# RGB
# calib_pos.csv
# 48
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_bottle/202009151716
# DEPTH
# RGB
# calib_pos.csv
# calib_pos_0.04166666666666667.csv
# 46
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_bottle/202009151717
# DEPTH
# RGB
# calib_pos.csv
# 52
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_bottle/202009151719
# DEPTH
# RGB
# calib_pos.csv
# 50
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_bottle/202009151720
# DEPTH
# RGB
# calib_pos.csv
# calib_pos_0.14166666666666672.csv
# 34
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_bottle/202009151721
# DEPTH
# RGB
# calib_pos.csv
# 43
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_bottle/202009151723
# DEPTH
# RGB
# calib_pos.csv
# 55
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_bottle/202009151724
# DEPTH
# RGB
# calib_pos.csv
# calib_pos_-0.058333333333333334.csv
# 42
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_bottle/202009151725
# DEPTH
# RGB
# calib_pos.csv
# calib_pos_-0.08333333333333333.csv
# 65
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_bottle/202009151727
# DEPTH
# RGB
# calib_pos.csv
# calib_pos_-0.10833333333333335.csv
# 34
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_bottle/202009151728
# DEPTH
# RGB
# calib_pos.csv
# 39
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_bottle/202009151730
# DEPTH
# RGB
# calib_pos.csv
# 36
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_bottle/202009151732
# DEPTH
# RGB
# calib_pos.csv
# calib_pos_-0.08333333333333333.csv
# 44
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_bottle/202009151733
# DEPTH
# RGB
# calib_pos.csv
# calib_pos_-0.08333333333333333.csv
# 54
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_bottle/202009151735
# DEPTH
# RGB
# calib_pos.csv
# 53
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_bottle/202009151737
# DEPTH
# RGB
# calib_pos.csv
# calib_pos_0.06666666666666667.csv
# 40
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_bottle/202009151738
# DEPTH
# RGB
# calib_pos.csv
# calib_pos_0.04166666666666667.csv
# 47
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_bottle/202009151740
# DEPTH
# RGB
# calib_pos.csv
# calib_pos_0.11666666666666668.csv
# 36
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_bottle/202009151741
# DEPTH
# RGB
# calib_pos.csv
# calib_pos_0.11666666666666668.csv
# 50
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_bottle/202009151745
# DEPTH
# RGB
# calib_pos.csv
# calib_pos_-0.03333333333333334.csv
# 50
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_bottle/202009151746
# DEPTH
# RGB
# calib_pos.csv
# 53
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_bottle/202009151748
# DEPTH
# RGB
# calib_pos.csv
# 46
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_bottle/202009151749
# DEPTH
# RGB
# calib_pos.csv
# calib_pos_0.11666666666666668.csv
# 49
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_bottle/202009151750
# DEPTH
# RGB
# calib_pos.csv
# 59
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_bottle/202009151751
# DEPTH
# RGB
# calib_pos.csv
# calib_pos_0.09166666666666666.csv
# 61
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_carrot/202009191652
# DEPTH
# RGB
# calib_pos.csv
# 36
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_carrot/202009191653
# DEPTH
# RGB
# calib_pos.csv
# calib_pos_0.04166666666666667.csv
# 32
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_carrot/202009191656
# DEPTH
# RGB
# calib_pos.csv
# 29
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_carrot/202009191657
# DEPTH
# RGB
# calib_pos.csv
# 41
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_carrot/202009191658
# DEPTH
# RGB
# calib_pos.csv
# calib_pos_0.09166666666666666.csv
# 38
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_carrot/202009191659
# DEPTH
# RGB
# calib_pos.csv
# 34
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_carrot/202009191700
# DEPTH
# RGB
# calib_pos.csv
# 39
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_carrot/202009191701
# DEPTH
# RGB
# calib_pos.csv
# 36
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_carrot/202009191702
# DEPTH
# RGB
# calib_pos.csv
# 37
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_carrot/202009191703
# DEPTH
# RGB
# calib_pos.csv
# calib_pos_0.14166666666666672.csv
# 39
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_carrot/202009191704
# DEPTH
# RGB
# calib_pos.csv
# calib_pos_0.09166666666666666.csv
# 29
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_carrot/202009191705
# DEPTH
# RGB
# calib_pos.csv
# 37
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_carrot/202009191706
# DEPTH
# RGB
# calib_pos.csv
# 31
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_carrot/202009191707
# DEPTH
# RGB
# calib_pos.csv
# 32
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_carrot/202009191708
# DEPTH
# RGB
# calib_pos.csv
# calib_pos_0.04166666666666667.csv
# 36
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_carrot/202009191709
# DEPTH
# RGB
# calib_pos.csv
# calib_pos_0.09166666666666666.csv
# 30
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_carrot/202009191710
# DEPTH
# RGB
# calib_pos.csv
# calib_pos_-0.008333333333333318.csv
# 39
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_carrot/202009191711
# DEPTH
# RGB
# calib_pos.csv
# 32
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_carrot/202009191712
# DEPTH
# RGB
# calib_pos.csv
# calib_pos_0.11666666666666668.csv
# 35
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_carrot/202009191713
# DEPTH
# RGB
# calib_pos.csv
# calib_pos_0.11666666666666668.csv
# 30
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_carrot/202009191715
# DEPTH
# RGB
# calib_pos.csv
# calib_pos_0.09166666666666666.csv
# 26
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_carrot/202009191716
# DEPTH
# RGB
# calib_pos.csv
# 29
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_carrot/202009191717
# DEPTH
# RGB
# calib_pos.csv
# 37
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_carrot/202009191719
# DEPTH
# RGB
# calib_pos.csv
# 37
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_carrot/202009191720
# DEPTH
# RGB
# calib_pos.csv
# calib_pos_0.06666666666666667.csv
# 32
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_carrot/202009191721
# DEPTH
# RGB
# calib_pos.csv
# calib_pos_0.09166666666666666.csv
# 41
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_carrot/202009191722
# DEPTH
# RGB
# calib_pos.csv
# calib_pos_0.1916666666666667.csv
# 23
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_carrot/202009191723
# DEPTH
# RGB
# calib_pos.csv
# 32
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_carrot/202009191724
# DEPTH
# RGB
# calib_pos.csv
# 37
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_carrot/202009191725
# DEPTH
# RGB
# calib_pos.csv
# calib_pos_0.1916666666666667.csv
# 33
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_cucumber/202008020522
# DEPTH
# RGB
# calib_pos.csv
# 55
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_cucumber/202008020526
# DEPTH
# RGB
# calib_pos.csv
# 49
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_cucumber/202008020528
# DEPTH
# RGB
# calib_pos.csv
# 46
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_cucumber/202008020530
# DEPTH
# RGB
# calib_pos.csv
# 49
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_cucumber/202008020531
# DEPTH
# RGB
# calib_pos.csv
# 38
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_cucumber/202008020533
# DEPTH
# RGB
# calib_pos.csv
# 47
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_cucumber/202008020535
# DEPTH
# RGB
# calib_pos.csv
# 51
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_cucumber/202008020537
# DEPTH
# RGB
# calib_pos.csv
# 44
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_cucumber/202008020539
# DEPTH
# RGB
# calib_pos.csv
# 39
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_cucumber/202008020540
# DEPTH
# RGB
# calib_pos.csv
# 37
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_cucumber/202008020542
# DEPTH
# RGB
# calib_pos.csv
# calib_pos_-0.058333333333333334.csv
# 32
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_cucumber/202008020543
# DEPTH
# RGB
# calib_pos.csv
# 46
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_cucumber/202008020544
# DEPTH
# RGB
# calib_pos.csv
# calib_pos_-0.058333333333333334.csv
# 66
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_cucumber/202008020546
# DEPTH
# RGB
# calib_pos.csv
# calib_pos_0.06666666666666667.csv
# 44
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_cucumber/202008020548
# DEPTH
# RGB
# calib_pos.csv
# 39
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_cucumber/202008020549
# DEPTH
# RGB
# calib_pos.csv
# 49
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_cucumber/202008020551
# DEPTH
# RGB
# calib_pos.csv
# 53
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_cucumber/202008020552
# DEPTH
# RGB
# calib_pos.csv
# 44
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_cucumber/202008020553
# DEPTH
# RGB
# calib_pos.csv
# 39
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_cucumber/202009091757
# DEPTH
# RGB
# calib_pos.csv
# calib_pos_0.1916666666666667.csv
# 22
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_cucumber/202009091758
# DEPTH
# RGB
# calib_pos.csv
# calib_pos_0.04166666666666667.csv
# 24
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_cucumber/202009091759
# DEPTH
# RGB
# calib_pos.csv
# 31
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_cucumber/202009091801
# DEPTH
# RGB
# calib_pos.csv
# calib_pos_0.06666666666666667.csv
# 30
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_cucumber/202009091802
# DEPTH
# RGB
# calib_pos.csv
# calib_pos_0.14166666666666672.csv
# 26
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_cucumber/202009091803
# DEPTH
# RGB
# calib_pos.csv
# calib_pos_-0.03333333333333334.csv
# 31
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_cucumber/202009091804
# DEPTH
# RGB
# calib_pos.csv
# 26
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_cucumber/202009091805
# DEPTH
# RGB
# calib_pos.csv
# calib_pos_-0.008333333333333318.csv
# 20
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_cucumber/202009091807
# DEPTH
# RGB
# calib_pos.csv
# calib_pos_0.06666666666666667.csv
# 28
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_cucumber/202009091808
# DEPTH
# RGB
# calib_pos.csv
# calib_pos_-0.2583333333333333.csv
# 31
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_cucumber/202009091809
# DEPTH
# RGB
# calib_pos.csv
# calib_pos_0.14166666666666672.csv
# 21
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_cucumber/202009091810
# DEPTH
# RGB
# calib_pos.csv
# calib_pos_0.09166666666666672.csv
# 23
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_cucumber/202009091811
# DEPTH
# RGB
# calib_pos.csv
# calib_pos_0.11666666666666668.csv
# 30
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_cucumber/202009091812
# DEPTH
# RGB
# calib_pos.csv
# calib_pos_-0.03333333333333331.csv
# 23
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_cucumber/202009091813
# DEPTH
# RGB
# calib_pos.csv
# calib_pos_-0.1333333333333333.csv
# 29
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_cucumber/202009091816
# DEPTH
# RGB
# calib_pos.csv
# calib_pos_0.14166666666666672.csv
# 27
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_cucumber/202009091817
# DEPTH
# RGB
# calib_pos.csv
# 20
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_cucumber/202009091818
# DEPTH
# RGB
# calib_pos.csv
# calib_pos_-0.008333333333333318.csv
# 24
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_cucumber/202009091819
# DEPTH
# RGB
# calib_pos.csv
# 27
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_cucumber/202009091820
# DEPTH
# RGB
# calib_pos.csv
# 15
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_cucumber/202009091821
# DEPTH
# RGB
# calib_pos.csv
# calib_pos_-0.058333333333333307.csv
# 28
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_cucumber/202009091822
# DEPTH
# RGB
# calib_pos.csv
# calib_pos_0.0666666666666667.csv
# 25
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_cucumber/202009091823
# DEPTH
# RGB
# calib_pos.csv
# 25
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_cucumber/202009191551
# DEPTH
# RGB
# calib_pos.csv
# calib_pos_0.0666666666666667.csv
# 24
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_cucumber/202009191555
# DEPTH
# RGB
# calib_pos.csv
# calib_pos_0.0666666666666667.csv
# 22
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_cucumber/202009191556
# DEPTH
# RGB
# calib_pos.csv
# calib_pos_-0.20833333333333331.csv
# 27
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_cucumber/202009191557
# DEPTH
# RGB
# calib_pos.csv
# calib_pos_0.11666666666666668.csv
# 31
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_cucumber/202009191558
# DEPTH
# RGB
# calib_pos.csv
# 29
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_cucumber/202009191559
# DEPTH
# RGB
# calib_pos.csv
# calib_pos_-0.0833333333333333.csv
# 36
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_cucumber/202009191600
# DEPTH
# RGB
# calib_pos.csv
# calib_pos_-0.0833333333333333.csv
# 30
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_cucumber/202009191601
# DEPTH
# RGB
# calib_pos.csv
# 31
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_cucumber/202009191602
# DEPTH
# RGB
# calib_pos.csv
# 36
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_cucumber/202009191603
# DEPTH
# RGB
# calib_pos.csv
# calib_pos_-0.008333333333333318.csv
# 33
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_cucumber/202009191605
# DEPTH
# RGB
# calib_pos.csv
# calib_pos_0.0666666666666667.csv
# 34
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_cucumber/202009191606
# DEPTH
# RGB
# calib_pos.csv
# 33
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_cucumber/202009191607
# DEPTH
# RGB
# calib_pos.csv
# 26
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_cucumber/202009191608
# DEPTH
# RGB
# calib_pos.csv
# 36
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_cucumber/202009191609
# DEPTH
# RGB
# calib_pos.csv
# 33
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_cucumber/202009191610
# DEPTH
# RGB
# calib_pos.csv
# 30
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_cucumber/202009191611
# DEPTH
# RGB
# calib_pos.csv
# calib_pos_0.11666666666666668.csv
# 25
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_cucumber/202009191612
# DEPTH
# RGB
# calib_pos.csv
# calib_pos_0.04166666666666673.csv
# 34
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_cucumber/202009191616
# DEPTH
# RGB
# calib_pos.csv
# 33
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_cucumber/202009191617
# DEPTH
# RGB
# calib_pos.csv
# 29
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_cucumber/202009191618
# DEPTH
# RGB
# calib_pos.csv
# 37
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_cucumber/202009191619
# DEPTH
# RGB
# calib_pos.csv
# calib_pos_-0.20833333333333331.csv
# 27
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_cucumber/202009191620
# DEPTH
# RGB
# calib_pos.csv
# 25
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_cucumber/202009191621
# DEPTH
# RGB
# calib_pos.csv
# calib_pos_0.0666666666666667.csv
# 28
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_cucumber/202009191622
# DEPTH
# RGB
# calib_pos.csv
# 32
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_cucumber/202009191623
# DEPTH
# RGB
# calib_pos.csv
# 31
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_cucumber/202009191624
# DEPTH
# RGB
# calib_pos.csv
# 37
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_cucumber/202009191625
# DEPTH
# RGB
# calib_pos.csv
# calib_pos_-0.058333333333333307.csv
# 27
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_cucumber/202009191626
# DEPTH
# RGB
# calib_pos.csv
# 34
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_cucumber/202009191627
# DEPTH
# RGB
# calib_pos.csv
# 33
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_cucumber/202009191629
# DEPTH
# RGB
# calib_pos.csv
# 26
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_cucumber/202009191630
# DEPTH
# RGB
# calib_pos.csv
# 27
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_cucumber/202009191631
# DEPTH
# RGB
# calib_pos.csv
# calib_pos_-0.0833333333333333.csv
# 32
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_cucumber/202009191632
# DEPTH
# RGB
# calib_pos.csv
# 38
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_cucumber/202009191633
# DEPTH
# RGB
# calib_pos.csv
# 38
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_cucumber/202009191635
# DEPTH
# RGB
# calib_pos.csv
# calib_pos_0.14166666666666672.csv
# 26
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_cucumber/202009191636
# DEPTH
# RGB
# calib_pos.csv
# calib_pos_-0.1333333333333333.csv
# 36
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_cucumber/202009191637
# DEPTH
# RGB
# calib_pos.csv
# 35
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_cucumber/202009191638
# DEPTH
# RGB
# calib_pos.csv
# calib_pos_0.14166666666666672.csv
# 36
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_cucumber/202009191639
# DEPTH
# RGB
# calib_pos.csv
# 35
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_eggplant/202008051559
# DEPTH
# RGB
# calib_pos.csv
# 39
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_eggplant/202008051601
# DEPTH
# RGB
# calib_pos.csv
# 41
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_eggplant/202008051602
# DEPTH
# RGB
# calib_pos.csv
# calib_pos_0.09166666666666672.csv
# 45
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_eggplant/202008051605
# DEPTH
# RGB
# calib_pos.csv
# 33
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_eggplant/202008051607
# DEPTH
# RGB
# calib_pos.csv
# 27
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_eggplant/202008051657
# DEPTH
# RGB
# calib_pos.csv
# 31
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_eggplant/202008051705
# DEPTH
# RGB
# calib_pos.csv
# 27
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_eggplant/202008051706
# DEPTH
# RGB
# calib_pos.csv
# 34
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_eggplant/202008051707
# DEPTH
# RGB
# calib_pos.csv
# calib_pos_0.0666666666666667.csv
# 30
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_eggplant/202008051709
# DEPTH
# RGB
# calib_pos.csv
# calib_pos_-0.0833333333333333.csv
# 31
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_eggplant/202008051710
# DEPTH
# RGB
# calib_pos.csv
# calib_pos_0.0666666666666667.csv
# 25
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_eggplant/202008051711
# DEPTH
# RGB
# calib_pos.csv
# 23
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_eggplant/202008051713
# DEPTH
# RGB
# calib_pos.csv
# 41
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_eggplant/202008051714
# DEPTH
# RGB
# calib_pos.csv
# 21
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_eggplant/202008051716
# DEPTH
# RGB
# calib_pos.csv
# 33
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_eggplant/202008051717
# DEPTH
# RGB
# calib_pos.csv
# calib_pos_0.0666666666666667.csv
# 27
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_eggplant/202008051718
# DEPTH
# RGB
# calib_pos.csv
# 14
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_eggplant/202009151811
# DEPTH
# RGB
# calib_pos.csv
# 34
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_eggplant/202009151814
# DEPTH
# RGB
# calib_pos.csv
# 29
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_eggplant/202009151815
# DEPTH
# RGB
# calib_pos.csv
# calib_pos_-0.1333333333333333.csv
# 26
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_eggplant/202009151817
# DEPTH
# RGB
# calib_pos.csv
# 33
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_eggplant/202009151818
# DEPTH
# RGB
# calib_pos.csv
# 29
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_eggplant/202009151819
# DEPTH
# RGB
# calib_pos.csv
# calib_pos_0.21666666666666673.csv
# 22
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_eggplant/202009151821
# DEPTH
# RGB
# calib_pos.csv
# 28
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_eggplant/202009151822
# DEPTH
# RGB
# calib_pos.csv
# 35
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_eggplant/202009151824
# DEPTH
# RGB
# calib_pos.csv
# calib_pos_0.09166666666666672.csv
# 30
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_eggplant/202009151825
# DEPTH
# RGB
# calib_pos.csv
# 31
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_eggplant/202009151826
# DEPTH
# RGB
# calib_pos.csv
# 29
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_eggplant/202009151827
# DEPTH
# RGB
# calib_pos.csv
# 29
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_eggplant/202009151828
# DEPTH
# RGB
# calib_pos.csv
# calib_pos_-0.008333333333333318.csv
# 25
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_eggplant/202009151829
# DEPTH
# RGB
# calib_pos.csv
# calib_pos_-0.058333333333333307.csv
# 28
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_eggplant/202009151831
# DEPTH
# RGB
# calib_pos.csv
# calib_pos_0.11666666666666668.csv
# 24
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_eggplant/202009151834
# DEPTH
# RGB
# calib_pos.csv
# calib_pos_0.09166666666666672.csv
# 29
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_eggplant/202009151835
# DEPTH
# RGB
# calib_pos.csv
# 34
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_eggplant/202009151837
# DEPTH
# RGB
# calib_pos.csv
# calib_pos_-0.0833333333333333.csv
# 29
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_eggplant/202009151838
# DEPTH
# RGB
# calib_pos.csv
# 25
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_eggplant/202009151839
# DEPTH
# RGB
# calib_pos.csv
# calib_pos_-0.1333333333333333.csv
# 31
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_eggplant/202009151840
# DEPTH
# RGB
# calib_pos.csv
# 25
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_eggplant/202009151841
# DEPTH
# RGB
# calib_pos.csv
# calib_pos_0.09166666666666672.csv
# 27
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_eggplant/202009151844
# DEPTH
# RGB
# calib_pos.csv
# calib_pos_-0.0833333333333333.csv
# 29
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_eggplant/202009151845
# DEPTH
# RGB
# calib_pos.csv
# 29
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_eggplant/202009151846
# DEPTH
# RGB
# calib_pos.csv
# 26
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_eggplant/202009151849
# DEPTH
# RGB
# calib_pos.csv
# 25
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_eggplant/202009151850
# DEPTH
# RGB
# calib_pos.csv
# 28
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_eggplant/202009151851
# DEPTH
# RGB
# calib_pos.csv
# calib_pos_-0.0833333333333333.csv
# 28
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_eggplant/202009151852
# DEPTH
# RGB
# calib_pos.csv
# calib_pos_-0.03333333333333331.csv
# 30
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_eggplant/202009151853
# DEPTH
# RGB
# calib_pos.csv
# calib_pos_0.09166666666666672.csv
# 30
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_eggplant/202009151854
# DEPTH
# RGB
# calib_pos.csv
# calib_pos_0.0666666666666667.csv
# 27
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_sp/202009191746
# DEPTH
# RGB
# calib_pos.csv
# 29
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_sp/202009191747
# DEPTH
# RGB
# calib_pos.csv
# calib_pos_0.09166666666666672.csv
# 37
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_sp/202009191748
# DEPTH
# RGB
# calib_pos.csv
# calib_pos_0.11666666666666668.csv
# 28
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_sp/202009191749
# DEPTH
# RGB
# calib_pos.csv
# 27
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_sp/202009191750
# DEPTH
# RGB
# calib_pos.csv
# calib_pos_-0.058333333333333307.csv
# 25
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_sp/202009191751
# DEPTH
# RGB
# calib_pos.csv
# 25
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_sp/202009191753
# DEPTH
# RGB
# calib_pos.csv
# 25
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_sp/202009191754
# DEPTH
# RGB
# calib_pos.csv
# calib_pos_0.14166666666666672.csv
# 20
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_sp/202009191755
# DEPTH
# RGB
# calib_pos.csv
# 29
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_sp/202009191758
# DEPTH
# RGB
# calib_pos.csv
# 41
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_sp/202009191759
# DEPTH
# RGB
# calib_pos.csv
# calib_pos_0.14166666666666672.csv
# 30
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_sp/202009191803
# DEPTH
# RGB
# calib_pos.csv
# calib_pos_-0.15833333333333333.csv
# 27
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_sp/202009191805
# DEPTH
# RGB
# calib_pos.csv
# 33
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_sp/202009191806
# DEPTH
# RGB
# calib_pos.csv
# calib_pos_0.11666666666666668.csv
# 29
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_sp/202009191807
# DEPTH
# RGB
# calib_pos.csv
# calib_pos_0.09166666666666672.csv
# 29
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_sp/202009191808
# DEPTH
# RGB
# calib_pos.csv
# calib_pos_0.0666666666666667.csv
# 34
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_sp/202009191809
# DEPTH
# RGB
# calib_pos.csv
# 32
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_sp/202009191810
# DEPTH
# RGB
# calib_pos.csv
# calib_pos_0.14166666666666672.csv
# 28
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_sp/202009191811
# DEPTH
# RGB
# calib_pos.csv
# calib_pos_-0.0833333333333333.csv
# 30
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_sp/202009191812
# DEPTH
# RGB
# calib_pos.csv
# 28
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_sp/202009211634
# DEPTH
# RGB
# calib_pos.csv
# 29
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_sp/202009211635
# DEPTH
# RGB
# calib_pos.csv
# calib_pos_-0.0833333333333333.csv
# 30
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_sp/202009211636
# DEPTH
# RGB
# calib_pos.csv
# calib_pos_-0.0833333333333333.csv
# 30
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_sp/202009211637
# DEPTH
# RGB
# calib_pos.csv
# calib_pos_0.16666666666666674.csv
# 32
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_sp/202009211638
# DEPTH
# RGB
# calib_pos.csv
# calib_pos_-0.1333333333333333.csv
# 34
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_sp/202009211639
# DEPTH
# RGB
# calib_pos.csv
# calib_pos_0.09166666666666672.csv
# 28
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_sp/202009211640
# DEPTH
# RGB
# calib_pos.csv
# calib_pos_-0.0833333333333333.csv
# 35
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_sp/202009211641
# DEPTH
# RGB
# calib_pos.csv
# calib_pos_0.11666666666666668.csv
# 27
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_sp/202009211642
# DEPTH
# RGB
# calib_pos.csv
# 28
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_sp/202009211643
# DEPTH
# RGB
# calib_pos.csv
# 43
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_sp/202009211645
# DEPTH
# RGB
# calib_pos.csv
# 29
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_sp/202009211646
# DEPTH
# RGB
# calib_pos.csv
# 43
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_sp/202009211647
# DEPTH
# RGB
# calib_pos.csv
# 37
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_sp/202009211648
# DEPTH
# RGB
# calib_pos.csv
# 42
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_sp/202009211649
# DEPTH
# RGB
# calib_pos.csv
# 31
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_sp/202009211650
# DEPTH
# RGB
# calib_pos.csv
# 34
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_sp/202009211651
# DEPTH
# RGB
# calib_pos.csv
# 37
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_sp/202009211652
# DEPTH
# RGB
# calib_pos.csv
# 28
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_sp/202009211653
# DEPTH
# RGB
# calib_pos.csv
# calib_pos_0.11666666666666668.csv
# 54
# /misc/dl00/tendon/project/Imitation_Learning/MotionPrediction/dataset/HMD/move_sp/202009211654
# DEPTH
# RGB
# calib_pos.csv
# 28

# %%
knife_center_list
# Out:
# [[array([nan, nan, nan])],
#  [array([nan, nan, nan])],
#  [array([nan, nan, nan])],
#  [array([nan, nan, nan])],
#  [array([nan, nan, nan])],
#  [array([nan, nan, nan])],
#  [array([nan, nan, nan])],
#  [array([nan, nan, nan])],
#  [array([nan, nan, nan])],
#  [array([nan, nan, nan])],
#  [array([nan, nan, nan])],
#  [array([nan, nan, nan])],
#  [array([nan, nan, nan])],
#  [array([nan, nan, nan])],
#  [array([nan, nan, nan])],
#  [array([nan, nan, nan])],
#  [array([nan, nan, nan])],
#  [array([nan, nan, nan])],
#  [array([nan, nan, nan])],
#  [array([nan, nan, nan])],
#  [array([nan, nan, nan])],
#  [array([nan, nan, nan])],
#  [array([nan, nan, nan])],
#  [array([nan, nan, nan])],
#  [array([nan, nan, nan])],
#  [array([nan, nan, nan])],
#  [array([nan, nan, nan])],
#  [array([nan, nan, nan])],
#  [array([nan, nan, nan])],
#  [array([nan, nan, nan])],
#  [array([nan, nan, nan])],
#  [array([nan, nan, nan])],
#  [array([nan, nan, nan])],
#  [array([nan, nan, nan])],
#  [array([nan, nan, nan])],
#  [array([nan, nan, nan])],
#  [array([nan, nan, nan])],
#  [array([nan, nan, nan])],
#  [array([nan, nan, nan])],
#  [array([nan, nan, nan])],
#  [array([nan, nan, nan])],
#  [array([nan, nan, nan])],
#  [array([nan, nan, nan])],
#  [array([nan, nan, nan])],
#  [array([nan, nan, nan])],
#  [array([nan, nan, nan])],
#  [array([nan, nan, nan])],
#  [array([nan, nan, nan])],
#  [array([nan, nan, nan])],
#  [array([nan, nan, nan])],
#  [array([nan, nan, nan])],
#  [array([nan, nan, nan])],
#  [array([nan, nan, nan])],
#  [array([nan, nan, nan])],
#  [array([nan, nan, nan])],
#  [array([nan, nan, nan])],
#  [array([nan, nan, nan])],
#  [array([nan, nan, nan])],
#  [array([nan, nan, nan])],
#  [array([nan, nan, nan])],
#  [array([nan, nan, nan])],
#  [array([nan, nan, nan])],
#  [array([nan, nan, nan])],
#  [array([nan, nan, nan])],
#  [array([nan, nan, nan])],
#  [array([nan, nan, nan])],
#  [array([nan, nan, nan])],
#  [array([nan, nan, nan])],
#  [array([nan, nan, nan])],
#  [array([nan, nan, nan])],
#  [array([nan, nan, nan])],
#  [array([nan, nan, nan])],
#  [array([nan, nan, nan])],
#  [array([nan, nan, nan])],
#  [array([nan, nan, nan])],
#  [array([nan, nan, nan])],
#  [array([nan, nan, nan])],
#  [array([nan, nan, nan])],
#  [array([nan, nan, nan])],
#  [array([nan, nan, nan])],
#  [array([nan, nan, nan])],
#  [array([nan, nan, nan])],
#  [array([nan, nan, nan])],
#  [array([nan, nan, nan])],
#  [array([nan, nan, nan])],
#  [array([nan, nan, nan])],
#  [array([nan, nan, nan])]]

# %%
rgb_image
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=448x224 at 0x7F35D302E940>

# %%
rgb_image_for_knife
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=448x224 at 0x7F35D3081E48>

# %%
hand_center_list
# Out:
# [[array([186.51049179, 163.55263711,   1.        ])],
#  [array([187.28603447, 164.07376718,   1.        ])],
#  [array([190.8307056 , 164.26427501,   1.        ])],
#  [array([195.41047603, 162.62799583,   1.        ])],
#  [array([199.69383843, 160.6708519 ,   1.        ])],
#  [array([204.04188212, 158.68710692,   1.        ])],
#  [array([207.9370981 , 156.44131122,   1.        ])],
#  [array([211.72138969, 154.11760846,   1.        ])],
#  [array([211.79562301, 154.11659182,   1.        ])],
#  [array([211.49900343, 153.98632015,   1.        ])],
#  [array([211.49867657, 153.92184987,   1.        ])],
#  [array([211.45587262, 153.89737925,   1.        ])],
#  [array([211.42243676, 153.92940205,   1.        ])],
#  [array([211.35976561, 154.00357091,   1.        ])],
#  [array([211.27368652, 154.22386636,   1.        ])],
#  [array([211.25411518, 154.60116299,   1.        ])],
#  [array([211.27904491, 154.70909718,   1.        ])],
#  [array([211.24682946, 154.6193333 ,   1.        ])],
#  [array([211.18666964, 154.48095492,   1.        ])],
#  [array([211.1605074 , 154.37275829,   1.        ])],
#  [array([211.13721313, 153.932579  ,   1.        ])],
#  [array([nan, nan, nan])],
#  [array([211.00817509, 154.03510849,   1.        ])],
#  [array([211.07004201, 153.99950575,   1.        ])],
#  [array([210.93794237, 154.17916949,   1.        ])],
#  [array([211.16064156, 154.3321406 ,   1.        ])],
#  [array([211.18494402, 154.12825351,   1.        ])],
#  [array([nan, nan, nan])],
#  [array([211.11040858, 154.16960758,   1.        ])],
#  [array([211.14700477, 154.21047573,   1.        ])],
#  [array([211.20401207, 154.25367844,   1.        ])],
#  [array([211.14697728, 154.20398758,   1.        ])],
#  [array([210.90094828, 154.18369984,   1.        ])]]
